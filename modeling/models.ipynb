# %%
import pandas as pd

# %%
data = pd.read_csv("train.csv")

# %%
data
# Out:
#         id  Age     BusinessTravel  DailyRate              Department  \
# 0        0   36  Travel_Frequently        599  Research & Development
# 1        1   35      Travel_Rarely        921                   Sales
# 2        2   32      Travel_Rarely        718                   Sales
# 3        3   38      Travel_Rarely       1488  Research & Development
# 4        4   50      Travel_Rarely       1017  Research & Development
# ...    ...  ...                ...        ...                     ...
# 1672  1672   30      Travel_Rarely        945                   Sales
# 1673  1673   32      Travel_Rarely       1303  Research & Development
# 1674  1674   29  Travel_Frequently       1184         Human Resources
# 1675  1675   36      Travel_Rarely        441                   Sales
# 1676  1676   36      Travel_Rarely       1141  Research & Development
#
#       DistanceFromHome  Education   EducationField  EmployeeCount  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1677 entries, 0 to 1676
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        1677 non-null   int64
#  1   Age                       1677 non-null   int64
#  2   BusinessTravel            1677 non-null   object
#  3   DailyRate                 1677 non-null   int64
#  4   Department                1677 non-null   object
#  5   DistanceFromHome          1677 non-null   int64
#  6   Education                 1677 non-null   int64
#  7   EducationField            1677 non-null   object
#  8   EmployeeCount             1677 non-null   int64
#  9   EnvironmentSatisfaction   1677 non-null   int64
#  10  Gender                    1677 non-null   object
#  11  HourlyRate                1677 non-null   int64
#  12  JobInvolvement            1677 non-null   int64
#  13  JobLevel                  1677 non-null   int64
# ...

# %%
data.columns
# Out:
# Index(['id', 'Age', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'Attrition'],
#       dtype='object')

# %%
data = pd.get_dummies(data, columns=['BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'Over18', 'OverTime'], drop_first=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1677 entries, 0 to 1676
# Data columns (total 48 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   id                                 1677 non-null   int64
#  1   Age                                1677 non-null   int64
#  2   DailyRate                          1677 non-null   int64
#  3   DistanceFromHome                   1677 non-null   int64
#  4   Education                          1677 non-null   int64
#  5   EmployeeCount                      1677 non-null   int64
#  6   EnvironmentSatisfaction            1677 non-null   int64
#  7   HourlyRate                         1677 non-null   int64
#  8   JobInvolvement                     1677 non-null   int64
#  9   JobLevel                           1677 non-null   int64
#  10  JobSatisfaction                    1677 non-null   int64
# ...

# %%
data.isnull().sum()
# Out:
# id                                   0
# Age                                  0
# DailyRate                            0
# DistanceFromHome                     0
# Education                            0
# EmployeeCount                        0
# EnvironmentSatisfaction              0
# HourlyRate                           0
# JobInvolvement                       0
# JobLevel                             0
# JobSatisfaction                      0
# MonthlyIncome                        0
# MonthlyRate                          0
# NumCompaniesWorked                   0
# PercentSalaryHike                    0
# PerformanceRating                    0
# RelationshipSatisfaction             0
# StandardHours                        0
# StockOptionLevel                     0
# TotalWorkingYears                    0
# TrainingTimesLastYear                0
# WorkLifeBalance                      0
# YearsAtCompany                       0
# YearsInCurrentRole                   0
# ...

# %%
# data2 = data[['Age', 'BusinessTravel', 'DailyRate', 'EnvironmentSatisfaction', 'JobRole', 'JobSatisfaction', 'MonthlyIncome', 'NumCompaniesWorked', 'OverTime', 'TotalWorkingYears', 'WorkLifeBalance', 'YearsAtCompany', 'YearsSinceLastPromotion', 'Attrition']]

# %%
from sklearn.ensemble import RandomForestClassifier

# Assuming 'data' is your DataFrame containing the required columns
X = data.drop(columns=['Attrition'])  # Features
y = data['Attrition']  # Target

rf = RandomForestClassifier()
rf.fit(X, y)

# Get feature importances
feature_importances = pd.DataFrame(rf.feature_importances_, index=X.columns, columns=['Importance'])
feature_importances = feature_importances.sort_values('Importance', ascending=False)

# Select top features
selected_features = feature_importances.head(10)  # Selecting top 10 features as an example

# %%
feature_importances
# Out:
#                                    Importance
# MonthlyIncome                        0.069581
# id                                   0.052302
# Age                                  0.052185
# MonthlyRate                          0.052136
# DailyRate                            0.049342
# TotalWorkingYears                    0.046714
# YearsAtCompany                       0.043915
# HourlyRate                           0.042622
# DistanceFromHome                     0.038477
# PercentSalaryHike                    0.038005
# StockOptionLevel                     0.037053
# YearsInCurrentRole                   0.033773
# JobInvolvement                       0.032558
# OverTime_Yes                         0.029849
# YearsWithCurrManager                 0.028838
# RelationshipSatisfaction             0.026965
# NumCompaniesWorked                   0.026239
# YearsSinceLastPromotion              0.025408
# EnvironmentSatisfaction              0.024382
# ...

# %%
data2 = data.drop(["EmployeeCount", "StandardHours", "id"], axis=1)

# %%
# # Selecting required columns
# selected_columns = ['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome', 'Education', 'EducationField', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Attrition']

# # Subsetting the data
# data_subset = data[selected_columns].copy()  # Use .copy() here

# # Feature Engineering
# data_subset['Experience'] = data_subset[['YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']].sum(axis=1)
# data_subset['DistanceFromHomeScore'] = data_subset['DistanceFromHome'].apply(lambda x: 'Short' if x < 5 else ('Medium' if x < 15 else 'Long'))
# data_subset['SpecializedEducation'] = data_subset['Education'].astype(str) + "_" + data_subset['EducationField']
# data_subset['Tenure'] = data_subset['TotalWorkingYears'] - data_subset['YearsAtCompany']
# data_subset['IncomePerYear'] = data_subset['MonthlyIncome'] / (data_subset['TotalWorkingYears'] + 1)

# # Encoding categorical variables
# categorical_columns = ['BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'DistanceFromHomeScore', 'SpecializedEducation']
# data_encoded = pd.get_dummies(data_subset, columns=categorical_columns, drop_first=True)

# # Dropping original and unnecessary columns
# columns_to_drop = ['DistanceFromHome', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Education']
# data_encoded.drop(columns=columns_to_drop, inplace=True)

# data2 = data_subset
# data2 = data_encoded

# %%
# from sklearn.preprocessing import LabelEncoder

# %%
# le = LabelEncoder()

# %%
# data2 = pd.get_dummies(data2, columns=['BusinessTravel', 'JobRole', 'OverTime'], drop_first=True)

# %%
data2.isnull().sum()
# Out:
# Age                                  0
# DailyRate                            0
# DistanceFromHome                     0
# Education                            0
# EnvironmentSatisfaction              0
# HourlyRate                           0
# JobInvolvement                       0
# JobLevel                             0
# JobSatisfaction                      0
# MonthlyIncome                        0
# MonthlyRate                          0
# NumCompaniesWorked                   0
# PercentSalaryHike                    0
# PerformanceRating                    0
# RelationshipSatisfaction             0
# StockOptionLevel                     0
# TotalWorkingYears                    0
# TrainingTimesLastYear                0
# WorkLifeBalance                      0
# YearsAtCompany                       0
# YearsInCurrentRole                   0
# YearsSinceLastPromotion              0
# YearsWithCurrManager                 0
# Attrition                            0
# ...

# %%
data2.dropna(how="any", inplace=True)

# %%
data2
# Out:
#       Age  DailyRate  DistanceFromHome  Education  EnvironmentSatisfaction  \
# 0      36        599                24          3                        4
# 1      35        921                 8          3                        1
# 2      32        718                26          3                        3
# 3      38       1488                 2          3                        3
# 4      50       1017                 5          4                        2
# ...   ...        ...               ...        ...                      ...
# 1672   30        945                 1          3                        4
# 1673   32       1303                 2          3                        1
# 1674   29       1184                24          3                        2
# 1675   36        441                 9          2                        2
# 1676   36       1141                20          3                        3
#
# ...

# %%
features = data2.drop("Attrition", axis=1)

# %%
features
# Out:
#       Age  DailyRate  DistanceFromHome  Education  EnvironmentSatisfaction  \
# 0      36        599                24          3                        4
# 1      35        921                 8          3                        1
# 2      32        718                26          3                        3
# 3      38       1488                 2          3                        3
# 4      50       1017                 5          4                        2
# ...   ...        ...               ...        ...                      ...
# 1672   30        945                 1          3                        4
# 1673   32       1303                 2          3                        1
# 1674   29       1184                24          3                        2
# 1675   36        441                 9          2                        2
# 1676   36       1141                20          3                        3
#
# ...

# %%
target = data2.Attrition

# %%
from sklearn.model_selection import train_test_split

# %%
features_train, features_test, target_train, target_test = train_test_split(features, target, test_size=0.3)

# %%
# from sklearn.linear_model import LogisticRegression

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import VotingClassifier

# %%
# Define individual models
model1 = RandomForestClassifier()
model2 = LogisticRegression(max_iter=10000)

# Create a voting classifier
ensemble_model = VotingClassifier(estimators=[('rf', model1), ('lr', model2)], voting='soft')

# %%
# from xgboost import XGBClassifier

# %%
# from sklearn.svm import SVC

# %%
from sklearn.metrics import accuracy_score, classification_report

# %%
# algorithmLR = LogisticRegression(max_iter=10000)

# %%
# algorithmRFC = RandomForestClassifier()

# %%
# algorithmXGBC = XGBClassifier()

# %%
# algorithmSVC = SVC(probability=True)

# %%
# modelLR = algorithmLR.fit(features_train, target_train)

# %%
# predictionLR = modelLR.predict(features_test)

# %%
# accuracyLR = accuracy_score(target_test, predictionLR)

# %%
# classLR = classification_report(target_test, predictionLR)

# %%
features
# Out:
#       Age  DailyRate  DistanceFromHome  Education  EnvironmentSatisfaction  \
# 0      36        599                24          3                        4
# 1      35        921                 8          3                        1
# 2      32        718                26          3                        3
# 3      38       1488                 2          3                        3
# 4      50       1017                 5          4                        2
# ...   ...        ...               ...        ...                      ...
# 1672   30        945                 1          3                        4
# 1673   32       1303                 2          3                        1
# 1674   29       1184                24          3                        2
# 1675   36        441                 9          2                        2
# 1676   36       1141                20          3                        3
#
# ...

# %%
# attritionProbLR = modelLR.predict_proba(features_test)[:, 1]

# %%
# attritionProbLR

# %%
# attritionProbLR_df = pd.DataFrame(attritionProbLR, columns=['Attrition_Probability'])

# %%
# data_with_attritionLR = pd.merge(data, attritionProbLR_df, left_index=True, right_index=True)

# %%
# dataLR = data_with_attritionLR[['id', 'Attrition_Probability']]

# %%
modelRFC = ensemble_model.fit(features_train, target_train)

# %%
predictionRFC = modelRFC.predict(features_test)

# %%
accuracyRFC = accuracy_score(target_test, predictionRFC)

# %%
classRFC = classification_report(target_test, predictionRFC)

# %%
attritionProbRFC = modelRFC.predict_proba(features_test)[:, 1]

# %%
attritionProbRFC
# Out:
# array([3.33433745e-01, 5.37003569e-01, 1.71371644e-02, 1.30987292e-01,
#        2.09703417e-01, 8.19180452e-02, 2.11508321e-01, 4.43525172e-01,
#        1.15653373e-02, 2.91841062e-01, 5.20152306e-02, 9.84601052e-02,
#        4.42113008e-02, 2.19926836e-02, 8.74407812e-02, 3.17561770e-01,
#        2.56182692e-02, 6.77218194e-01, 7.83390927e-02, 3.85814756e-01,
#        8.00827114e-03, 1.68499981e-01, 1.73679634e-02, 1.75331020e-01,
#        1.07169833e-01, 1.84529935e-01, 3.49613634e-02, 2.16938395e-01,
#        2.11948506e-01, 5.24792102e-02, 7.58033523e-02, 1.99777109e-02,
#        7.66423023e-02, 2.27904152e-02, 1.67564501e-01, 3.51996018e-01,
#        8.51909828e-02, 2.53321048e-01, 4.02031432e-02, 6.22055278e-02,
#        2.29270722e-01, 4.81475122e-02, 2.87370005e-01, 1.25659126e-01,
#        2.58124920e-01, 2.93553869e-01, 5.34941997e-01, 1.61333084e-01,
#        3.63161811e-01, 9.89775654e-02, 1.63704698e-01, 2.93269774e-02,
# ...

# %%
attritionProbRFC_df = pd.DataFrame(attritionProbRFC, columns=['Attrition_Probability'])

# %%
data_with_attritionRFC = pd.merge(data, attritionProbRFC_df, left_index=True, right_index=True)

# %%
dataRFC = data_with_attritionRFC[['id', 'Attrition_Probability']]

# %%
# modelXGBC = algorithmXGBC.fit(features_train, target_train)

# %%
# predictionXGBC = modelXGBC.predict(features_test)

# %%
# accuracyXGBC = accuracy_score(target_test, predictionXGBC)

# %%
# classXGBC = classification_report(target_test, predictionXGBC)

# %%
# modelSVC = algorithmSVC.fit(features_train, target_train)

# %%
# predictionSVC = modelSVC.predict(features_test)

# %%
# accuracySVC = accuracy_score(target_test, predictionSVC)

# %%
# classSVC = classification_report(target_test, predictionSVC,zero_division=1)

# %%
# attritionProbSVC = modelSVC.predict_proba(features)[:, 1]

# %%
# attritionProbSVC

# %%
# attritionProbSVC_df = pd.DataFrame(attritionProbSVC, columns=['Attrition_Probability'])

# %%
# data_with_attritionSVC = pd.merge(data, attritionProbSVC_df, left_index=True, right_index=True)

# %%
# dataSVC = data_with_attritionSVC[['id', 'Attrition_Probability']]

# %%
# dataSVC = dataSVC.head(1119)

# %%
# dataSVC

# %%
# print(f"Logistic Regression\nAccuracy: {accuracyLR}\n{classLR}\n\n")

# %%
print(f"Random Forest\nAccuracy: {accuracyRFC}\n{classRFC}\n\n")
# Out:
# Random Forest
# Accuracy: 0.9087301587301587
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95       455
#            1       0.59      0.20      0.30        49
#
#     accuracy                           0.91       504
#    macro avg       0.75      0.59      0.63       504
# weighted avg       0.89      0.91      0.89       504

# %%
# print(f"SVM\nAccuracy: {accuracySVC}\n{classSVC}\n\n")

# %%
# dataLR.to_csv('data_with_attritionLR.csv', index=False)

# %%
# dataRFC.to_csv('data_with_attritionRFC.csv', index=False)

# %%
data1 = pd.read_csv("test.csv")

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1119 entries, 0 to 1118
# Data columns (total 34 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        1119 non-null   int64
#  1   Age                       1119 non-null   int64
#  2   BusinessTravel            1119 non-null   object
#  3   DailyRate                 1119 non-null   int64
#  4   Department                1119 non-null   object
#  5   DistanceFromHome          1119 non-null   int64
#  6   Education                 1119 non-null   int64
#  7   EducationField            1119 non-null   object
#  8   EmployeeCount             1119 non-null   int64
#  9   EnvironmentSatisfaction   1119 non-null   int64
#  10  Gender                    1119 non-null   object
#  11  HourlyRate                1119 non-null   int64
#  12  JobInvolvement            1119 non-null   int64
#  13  JobLevel                  1119 non-null   int64
# ...

# %%
data1 = pd.get_dummies(data1, columns=['BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'Over18', 'OverTime'], drop_first=True)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1119 entries, 0 to 1118
# Data columns (total 47 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   id                                 1119 non-null   int64
#  1   Age                                1119 non-null   int64
#  2   DailyRate                          1119 non-null   int64
#  3   DistanceFromHome                   1119 non-null   int64
#  4   Education                          1119 non-null   int64
#  5   EmployeeCount                      1119 non-null   int64
#  6   EnvironmentSatisfaction            1119 non-null   int64
#  7   HourlyRate                         1119 non-null   int64
#  8   JobInvolvement                     1119 non-null   int64
#  9   JobLevel                           1119 non-null   int64
#  10  JobSatisfaction                    1119 non-null   int64
# ...

# %%
data1.isnull().sum()
# Out:
# id                                   0
# Age                                  0
# DailyRate                            0
# DistanceFromHome                     0
# Education                            0
# EmployeeCount                        0
# EnvironmentSatisfaction              0
# HourlyRate                           0
# JobInvolvement                       0
# JobLevel                             0
# JobSatisfaction                      0
# MonthlyIncome                        0
# MonthlyRate                          0
# NumCompaniesWorked                   0
# PercentSalaryHike                    0
# PerformanceRating                    0
# RelationshipSatisfaction             0
# StandardHours                        0
# StockOptionLevel                     0
# TotalWorkingYears                    0
# TrainingTimesLastYear                0
# WorkLifeBalance                      0
# YearsAtCompany                       0
# YearsInCurrentRole                   0
# ...

# %%
data3 = data1.drop(["EmployeeCount", "StandardHours", "id"], axis=1)

# %%
data3.dropna(how="any", inplace=True)

# %%
# predictionLR1 = modelLR.predict(data3)

# %%
predictionRFC1 = modelRFC.predict(data3)

# %%
# predictionSVC1 = modelSVC.predict(data3)

# %%
attritionProbRFC1 = modelRFC.predict_proba(data3)[:, 1]

# %%
attritionProbRFC_df1 = pd.DataFrame(attritionProbRFC1, columns=['Attrition'])

# %%
data_with_attritionRFC1 = pd.merge(data1, attritionProbRFC_df1, left_index=True, right_index=True)

# %%
dataRFC1 = data_with_attritionRFC1[['id', 'Attrition']]

# %%
dataRFC1
# Out:
#         id  Attrition
# 0     1677   0.311852
# 1     1678   0.145137
# 2     1679   0.062643
# 3     1680   0.071620
# 4     1681   0.435826
# ...    ...        ...
# 1114  2791   0.127450
# 1115  2792   0.007800
# 1116  2793   0.014913
# 1117  2794   0.070454
# 1118  2795   0.021950
#
# [1119 rows x 2 columns]

# %%
dataRFC1.to_csv('data_with_attrition2.csv', index=False)
